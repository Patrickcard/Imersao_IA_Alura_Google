# %% [markdown]
# <a href="https://colab.research.google.com/github/Patrickcard/Imersao_IA_Alura_Google/blob/main/Chatbot_Para_Artistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai


import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get("Secret_Key")
genai.configure(api_key=api_key)

generation_config = {
    "candidate_count": 1,
    "temperature": 0.5,
}


safety_settings = {
    "HARASSMENT": "BLOCK_NONE",
    "HATE": "BLOCK_NONE",
    "SEXUAL": "BLOCK_NONE",
    "DANGEROUS": "BLOCK_NONE",
}


model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings= safety_settings)

#Iniciar a conversa
def start_chat():
  chat = model.start_chat(history = [])
  return chat


#Entrada do usuário e obter a resposta do chatbot
def get_response(chat, user_input):
  response = chat.send_message(user_input)
  return response.text


#função principal do chatbot
def main():
  print("Seja bem vindo! Serei seu amigo em suas criações artisticas. Vamos começar.","\n")
  print("Digite 'sair' a qualquer momento para encerrar a conversa.","\n")
  print("Como posso ajuda-lo hoje?","\n")

chat = start_chat()


if __name__ == "__main__":
  main()


while True:
  user_input= input("Você: ",)
  if user_input.lower() == "sair":
    print("Espero ter ajudado em sua jornada artistica. Até mais!")
    break

  response = get_response(chat, user_input)

  print("Chatbot: ", response)
# Out:
# Seja bem vindo! Serei seu amigo em suas criações artisticas. Vamos começar.
#
# Digite 'sair' a qualquer momento para encerrar a conversa.
#
# Como posso ajuda-lo hoje?
#
# Você: me faça relaxar
# Chatbot:  **Exercícios de Respiração Profunda**
#
# * Sente-se ou deite-se confortavelmente.
# * Coloque uma mão no peito e a outra no abdômen.
# * Inspire lentamente pelo nariz, enchendo primeiro o abdômen e depois o peito.
# * Exale lentamente pela boca, esvaziando primeiro o peito e depois o abdômen.
# * Repita por 5 a 10 minutos.
#
# **Meditação de Atenção Plena**
#
# * Sente-se em uma posição confortável.
# * Feche os olhos e concentre-se na sua respiração.
# * Observe a sensação do ar entrando e saindo do seu corpo.
# * Quando sua mente vagar, gentilmente traga-a de volta para a respiração.
# * Continue por 5 a 10 minutos.
#
# **Visualização**
#
# * Feche os olhos e imagine um lugar tranquilo e relaxante.
# * Pode ser uma praia, uma floresta ou um jardim.
# * Concentre-se nos detalhes sensoriais, como o som das ondas, o cheiro das flores ou a brisa suave.
# * Imagine-se neste lugar, sentindo-se calmo e sereno.
# * Continue por 5 a 10 minutos.
#
# **Massagem**
#
# * Peça a alguém para lhe dar uma massagem suave.
# * Concentre-se na sensação das mãos tocando seu corpo.
# * Respire profundamente e permita que a tensão se dissipe.
#
# **Música Calmante**
#
# * Ouça música relaxante ou sons da natureza.
# * Feche os olhos e deixe a música acalmar sua mente.
# * Concentre-se nas melodias e ritmos, deixando que eles levem você a um estado de relaxamento.
#
# **Banho Quente**
#
# * Tome um banho quente com sais de banho ou óleos essenciais calmantes.
# * Deixe a água quente relaxar seus músculos e aliviar o estresse.
# * Feche os olhos e desfrute da sensação de calor e conforto.
#
# **Atividade Física Leve**
#
# * Envolva-se em atividades físicas leves, como ioga, tai chi ou caminhada.
# * O exercício libera endorfinas, que têm efeitos calmantes.
# * Concentre-se em seus movimentos e na conexão mente-corpo.
# Você: sair
# Espero ter ajudado em sua jornada artistica. Até mais!
